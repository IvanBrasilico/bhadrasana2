# %%
import os
import pickle
import pandas as pd

os.getcwd()
os.chdir('../../..')
os.getcwd()
# Out:
# 'C:\\Users\\25052288840\\PycharmProjects\\bhadrasana2'

# %%
print([filename for filename in os.listdir() if '.pickle' in filename])
# Out:
# ['sizes_recinto2020311-2.pickle', 'sizes_recinto2020311.pickle']

# %%
with open('sizes_recinto2020311-2.pickle', 'rb') as handle:
    sizes_recinto = pickle.load(handle)

# %%
sizes_listed = []
for recinto, sizes in sizes_recinto.items():
    for size in sizes:
        cols, rows = size
        sizes_listed.append((recinto, cols, rows))

# %%
df = pd.DataFrame(sizes_listed, columns = ['recinto', 'cols', 'rows'])
df['ratio'] = df['cols'] / df['rows']

# %%
print(df.shape)
df.head()
# Out:
# (10000, 4)
#    recinto  cols  rows     ratio
# 0  DEICMAR  1654   799  2.070088
# 1  DEICMAR  1817   799  2.274093
# 2  DEICMAR  1759   799  2.201502
# 3  DEICMAR  1632   799  2.042553
# 4  DEICMAR  1628   799  2.037547

# %%
df.describe()
# Out:
#                cols         rows         ratio
# count  10000.000000  10000.00000  10000.000000
# mean    2038.917800    790.76750      2.607336
# std      646.850885     90.06035      0.810599
# min       90.000000    192.00000      0.112782
# 25%     1690.000000    799.00000      2.137500
# 50%     1923.500000    799.00000      2.434293
# 75%     2261.000000    799.00000      2.887672
# max     5705.000000    880.00000      7.140175

# %%
df.groupby('recinto').describe()
# Out:
#                 cols                                                    \
#                count         mean         std     min      25%     50%
# recinto
# APMT           465.0  1362.735484  386.579068   719.0  1081.00  1277.0
# BANDEIRANTES   264.0  1922.155303  588.365069   854.0  1594.00  1786.0
# BTP1          1811.0  1931.342352  345.368782  1039.0  1684.00  1908.0
# DEICMAR        488.0  1784.799180  296.358537  1231.0  1576.75  1734.0
# ECOPORTO       656.0  2078.007622  412.752202    90.0  1861.50  2054.5
# EMBRAPORT      890.0  3425.440449  675.352334  1072.0  3037.25  3416.5
# EUDMARCO       212.0   768.000000    0.000000   768.0   768.00   768.0
# LOCALFRIO      480.0  1737.264583  174.053452   594.0  1676.00  1734.0
# MARIMEX        703.0  2041.300142  541.582339   992.0  1654.50  1972.0
# NOVALOG        515.0  1789.910680  155.990072   935.0  1741.00  1804.0
# PNV            108.0  1203.101852  297.919921   731.0  1007.75  1153.5
# SBT           3138.0  2065.569790  395.130908   825.0  1798.00  2029.0
# TRANSBRASA     270.0  1860.611111  336.561633  1076.0  1664.50  1870.5
#
#                                  rows              ...                 ratio  \
#                   75%     max   count        mean  ...    75%    max   count
# recinto                                            ...
# APMT          1591.00  2623.0   465.0  878.993548  ...  879.0  880.0   465.0
# BANDEIRANTES  2127.25  4216.0   264.0  799.344697  ...  800.0  800.0   264.0
# BTP1          2126.00  3696.0  1811.0  799.027057  ...  799.0  800.0  1811.0
# DEICMAR       1948.00  3287.0   488.0  799.018443  ...  799.0  800.0   488.0
# ECOPORTO      2268.50  5107.0   656.0  798.998476  ...  799.0  800.0   656.0
# EMBRAPORT     3825.00  5705.0   890.0  799.300000  ...  800.0  800.0   890.0
# EUDMARCO       768.00   768.0   212.0  192.000000  ...  192.0  192.0   212.0
# LOCALFRIO     1799.75  2496.0   480.0  799.002083  ...  799.0  800.0   480.0
# MARIMEX       2338.00  4367.0   703.0  799.028450  ...  799.0  800.0   703.0
# NOVALOG       1874.00  2083.0   515.0  799.001942  ...  799.0  800.0   515.0
# PNV           1354.00  2210.0   108.0  878.990741  ...  879.0  879.0   108.0
# SBT           2298.50  4423.0  3138.0  799.026131  ...  799.0  800.0  3138.0
# TRANSBRASA    2043.00  2815.0   270.0  799.014815  ...  799.0  800.0   270.0
#
#                                                                           \
#                   mean       std       min       25%       50%       75%
# recinto
# APMT          1.550329  0.439776  0.817975  1.229807  1.452787  1.810011
# BANDEIRANTES  2.404661  0.736060  1.068836  1.994994  2.233895  2.662390
# BTP1          2.417119  0.432243  1.300375  2.107635  2.387985  2.660826
# DEICMAR       2.233738  0.370891  1.540676  1.973404  2.170213  2.438048
# ECOPORTO      2.600741  0.516572  0.112782  2.329787  2.571339  2.839174
# EMBRAPORT     4.285539  0.844857  1.341677  3.800250  4.272500  4.784620
# EUDMARCO      4.000000  0.000000  4.000000  4.000000  4.000000  4.000000
# LOCALFRIO     2.174293  0.217843  0.743429  2.097622  2.170213  2.252503
# MARIMEX       2.554714  0.677731  1.241552  2.070713  2.468085  2.926158
# NOVALOG       2.240184  0.195238  1.170213  2.178974  2.257822  2.345432
# PNV           1.368726  0.338917  0.831627  1.146473  1.312287  1.540387
# SBT           2.585109  0.494520  1.032541  2.250313  2.539424  2.874961
# TRANSBRASA    2.328632  0.421229  1.346683  2.083229  2.341051  2.556946
#
#
#                    max
# recinto
# APMT          2.984073
# BANDEIRANTES  5.270000
# BTP1          4.625782
# DEICMAR       4.113892
# ECOPORTO      6.391740
# EMBRAPORT     7.140175
# EUDMARCO      4.000000
# LOCALFRIO     3.123905
# MARIMEX       5.465582
# NOVALOG       2.607009
# PNV           2.514221
# SBT           5.535670
# TRANSBRASA    3.523154
#
# [13 rows x 24 columns]

# %%
df.groupby('recinto')['ratio'].describe()
# Out:
#                count      mean       std       min       25%       50%  \
# recinto
# APMT           465.0  1.550329  0.439776  0.817975  1.229807  1.452787
# BANDEIRANTES   264.0  2.404661  0.736060  1.068836  1.994994  2.233895
# BTP1          1811.0  2.417119  0.432243  1.300375  2.107635  2.387985
# DEICMAR        488.0  2.233738  0.370891  1.540676  1.973404  2.170213
# ECOPORTO       656.0  2.600741  0.516572  0.112782  2.329787  2.571339
# EMBRAPORT      890.0  4.285539  0.844857  1.341677  3.800250  4.272500
# EUDMARCO       212.0  4.000000  0.000000  4.000000  4.000000  4.000000
# LOCALFRIO      480.0  2.174293  0.217843  0.743429  2.097622  2.170213
# MARIMEX        703.0  2.554714  0.677731  1.241552  2.070713  2.468085
# NOVALOG        515.0  2.240184  0.195238  1.170213  2.178974  2.257822
# PNV            108.0  1.368726  0.338917  0.831627  1.146473  1.312287
# SBT           3138.0  2.585109  0.494520  1.032541  2.250313  2.539424
# TRANSBRASA     270.0  2.328632  0.421229  1.346683  2.083229  2.341051
#
#                    75%       max
# recinto
# APMT          1.810011  2.984073
# BANDEIRANTES  2.662390  5.270000
# BTP1          2.660826  4.625782
# DEICMAR       2.438048  4.113892
# ECOPORTO      2.839174  6.391740
# EMBRAPORT     4.784620  7.140175
# EUDMARCO      4.000000  4.000000
# LOCALFRIO     2.252503  3.123905
# MARIMEX       2.926158  5.465582
# NOVALOG       2.345432  2.607009
# PNV           1.540387  2.514221
# SBT           2.874961  5.535670
# TRANSBRASA    2.556946  3.523154

# %%
# %matplotlib inline
df[df.recinto == 'BTP1']['ratio'].hist()

# %%
df[df.recinto == 'SBT']['ratio'].hist()

# %%
df[df.recinto == 'SBT'][df.ratio < 2]['ratio'].count() / df[df.recinto == 'SBT']['ratio'].count()
# Out:
# C:\Users\25052288840\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 0.09623964308476737

# %%
df[df.recinto == 'BTP1'][df.ratio < 2]['ratio'].count() / df[df.recinto == 'BTP1']['ratio'].count()
# Out:
# C:\Users\25052288840\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 0.15681943677526228
